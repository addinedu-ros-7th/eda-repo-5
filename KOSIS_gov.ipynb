# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %%
df= pd.read_csv("../data/gov_supp.csv", header=1, encoding='EUC-KR')
df.set_index('특성별(2)', inplace=True)
df.drop('소계', inplace = True)
df
# Out:
#              특성별(1) 사업체수 (개) 연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%)  \
# 특성별(2)
# 제조업용 로봇         업종별      525           42.9         16.1            5.7
# 전문서비스용 로봇       업종별      244           47.0         27.2              -
# 개인서비스용 로봇       업종별      106           29.5         21.6            6.2
# 로봇부품 및 소프트웨어    업종별     1360           39.6         22.8            2.1
# 로봇 시스템          업종별      742           47.9         22.5            2.8
# 로봇 임베디드         업종별      158           57.6         10.9              -
# 로봇 서비스          업종별     1175           22.9         36.4              -
# 1억원 미만         매출액별      692           37.1         29.8            1.2
# 1~5억원 미만       매출액별     1072           33.2         28.8            2.2
# 5~10억원 미만      매출액별      948           42.0         23.1            1.1
# 1~10억원 미만      매출액별        -              -            -              -
# 10~30억원 미만     매출액별     1030           38.6         22.4            2.4
# ...

# %% [markdown]
# #### *2019년도 데이터

# %%
df_2019 = df.iloc[0:, 1:11]
df_2019
# Out:
#              사업체수 (개) 연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇           525           42.9         16.1            5.7        13.5
# 전문서비스용 로봇         244           47.0         27.2              -         1.7
# 개인서비스용 로봇         106           29.5         21.6            6.2        16.5
# 로봇부품 및 소프트웨어     1360           39.6         22.8            2.1        12.7
# 로봇 시스템            742           47.9         22.5            2.8         9.7
# 로봇 임베디드           158           57.6         10.9              -        12.5
# 로봇 서비스           1175           22.9         36.4              -        13.0
# 1억원 미만            692           37.1         29.8            1.2         9.4
# 1~5억원 미만         1072           33.2         28.8            2.2         9.7
# 5~10억원 미만         948           42.0         23.1            1.1        13.1
# 1~10억원 미만           -              -            -              -           -
# ...

# %% [markdown]
# ##### 2019년도 업종별 데이터

# %%
df_2019_jobtype = df_2019.iloc[0:7, 1:]
df_2019_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                42.9         16.1            5.7        13.5
# 전문서비스용 로봇              47.0         27.2              -         1.7
# 개인서비스용 로봇              29.5         21.6            6.2        16.5
# 로봇부품 및 소프트웨어           39.6         22.8            2.1        12.7
# 로봇 시스템                 47.9         22.5            2.8         9.7
# 로봇 임베디드                57.6         10.9              -        12.5
# 로봇 서비스                 22.9         36.4              -        13.0
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%)  \
# 특성별(2)
# 제조업용 로봇                    10.8            5.0           5.3    0.7
# 전문서비스용 로봇                  14.1              -           9.9      -
# 개인서비스용 로봇                  15.1            1.7           6.2    1.2
# 로봇부품 및 소프트웨어                5.8            5.7          10.1    0.7
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
    df_2019_jobtype[name] = df_2019_jobtype[name].str.replace('-', '0')


df_2019_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                42.9         16.1            5.7        13.5
# 전문서비스용 로봇              47.0         27.2              0         1.7
# 개인서비스용 로봇              29.5         21.6            6.2        16.5
# 로봇부품 및 소프트웨어           39.6         22.8            2.1        12.7
# 로봇 시스템                 47.9         22.5            2.8         9.7
# 로봇 임베디드                57.6         10.9              0        12.5
# 로봇 서비스                 22.9         36.4              0        13.0
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%)  \
# 특성별(2)
# 제조업용 로봇                    10.8            5.0           5.3    0.7
# 전문서비스용 로봇                  14.1              0           9.9      0
# 개인서비스용 로봇                  15.1            1.7           6.2    1.2
# 로봇부품 및 소프트웨어                5.8            5.7          10.1    0.7
# ...

# %%
df_2019_jobtype = df_2019_jobtype.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2019_jobtype
# Out:
#               연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                 42.9          16.1             5.7         13.5
# 전문서비스용 로봇               47.0          27.2             0.0          1.7
# 개인서비스용 로봇               29.5          21.6             6.2         16.5
# 로봇부품 및 소프트웨어            39.6          22.8             2.1         12.7
# 로봇 시스템                  47.9          22.5             2.8          9.7
# 로봇 임베디드                 57.6          10.9             0.0         12.5
# 로봇 서비스                  22.9          36.4             0.0         13.0
#
#               해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 제조업용 로봇                     10.8             5.0            5.3     0.7
# 전문서비스용 로봇                   14.1             0.0            9.9     0.0
# 개인서비스용 로봇                   15.1             1.7            6.2     1.2
# 로봇부품 및 소프트웨어                 5.8             5.7           10.1     0.7
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2019_jobtype.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="업종별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2019년도 매출액별 데이터

# %%
df_2019_output = df_2019.iloc[7:16, 1:]
df_2019_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                37.1         29.8            1.2         9.4
# 1~5억원 미만              33.2         28.8            2.2         9.7
# 5~10억원 미만             42.0         23.1            1.1        13.1
# 1~10억원 미만                -            -              -           -
# 10~30억원 미만            38.6         22.4            2.4        13.5
# 30억원 이상               38.2         23.2            3.1        13.7
# 10~50억원 미만               -            -              -           -
# 50~100억원 미만              -            -              -           -
# 100억원 이상                 -            -              -           -
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1억원 미만                     3.2            2.2          16.6    0.6           -
# 1~5억원 미만                   4.1            6.6          14.4    0.6         0.5
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
    df_2019_output[name] = df_2019_output[name].str.replace('-', '0')

df_2019_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                37.1         29.8            1.2         9.4
# 1~5억원 미만              33.2         28.8            2.2         9.7
# 5~10억원 미만             42.0         23.1            1.1        13.1
# 1~10억원 미만                0            0              0           0
# 10~30억원 미만            38.6         22.4            2.4        13.5
# 30억원 이상               38.2         23.2            3.1        13.7
# 10~50억원 미만               0            0              0           0
# 50~100억원 미만              0            0              0           0
# 100억원 이상                 0            0              0           0
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1억원 미만                     3.2            2.2          16.6    0.6           0
# 1~5억원 미만                   4.1            6.6          14.4    0.6         0.5
# ...

# %%
df_2019_output = df_2019_output.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2019_output
# Out:
#              연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                 37.1          29.8             1.2          9.4
# 1~5억원 미만               33.2          28.8             2.2          9.7
# 5~10억원 미만              42.0          23.1             1.1         13.1
# 1~10억원 미만               0.0           0.0             0.0          0.0
# 10~30억원 미만             38.6          22.4             2.4         13.5
# 30억원 이상                38.2          23.2             3.1         13.7
# 10~50억원 미만              0.0           0.0             0.0          0.0
# 50~100억원 미만             0.0           0.0             0.0          0.0
# 100억원 이상                0.0           0.0             0.0          0.0
#
#              해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 1억원 미만                      3.2             2.2           16.6     0.6
# 1~5억원 미만                    4.1             6.6           14.4     0.6
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2019_output.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="매출액별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2019년도 종사자수별 데이터

# %%
df_2019_workers = df_2019.iloc[16:20, 1:]
df_2019_workers
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1~4인             26.6         32.1            1.5        15.2
# 5~9인             36.9         27.5            1.2        12.6
# 10~49인           45.7         20.6            2.7        11.6
# 50인 이상           39.0         22.8            1.9         2.5
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1~4인                  4.7            6.2          13.1    0.6           -
# 5~9인                  6.6            5.1           9.6    0.6           -
# 10~49인                8.6            4.0           6.7    0.1         0.1
# 50인 이상               12.5            5.5          13.7    0.2         1.9

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2019_workers[name] = df_2019_workers[name].str.replace('-', '0')

df_2019_workers
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1~4인             26.6         32.1            1.5        15.2
# 5~9인             36.9         27.5            1.2        12.6
# 10~49인           45.7         20.6            2.7        11.6
# 50인 이상           39.0         22.8            1.9         2.5
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1~4인                  4.7            6.2          13.1    0.6           0
# 5~9인                  6.6            5.1           9.6    0.6           0
# 10~49인                8.6            4.0           6.7    0.1         0.1
# 50인 이상               12.5            5.5          13.7    0.2         1.9

# %%
df_2019_workers = df_2019_workers.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2019_workers
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1~4인              26.6          32.1             1.5         15.2
# 5~9인              36.9          27.5             1.2         12.6
# 10~49인            45.7          20.6             2.7         11.6
# 50인 이상            39.0          22.8             1.9          2.5
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  모름/ 무응답 (%)
# 특성별(2)
# 1~4인                   4.7             6.2           13.1     0.6          0.0
# 5~9인                   6.6             5.1            9.6     0.6          0.0
# 10~49인                 8.6             4.0            6.7     0.1          0.1
# 50인 이상                12.5             5.5           13.7     0.2          1.9

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2019_workers.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="종사자수별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2019년도 권역별 데이터

# %%
df_2019_city = df_2019.iloc[20:24, 1:]
df_2019_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              38.1         23.2            1.5        12.3
# 영남권              34.0         33.1            2.4        11.7
# 충청권              35.5         26.7            5.7         8.1
# 호남권              64.9          4.8              -        11.4
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 수도권                   9.1            6.3           9.2    0.0         0.2
# 영남권                   4.5            2.3          11.1    0.5         0.4
# 충청권                   7.4            3.6          12.2    0.9           -
# 호남권                     -            5.4          10.5    3.0           -

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2019_city[name] = df_2019_city[name].str.replace('-', '0')

df_2019_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              38.1         23.2            1.5        12.3
# 영남권              34.0         33.1            2.4        11.7
# 충청권              35.5         26.7            5.7         8.1
# 호남권              64.9          4.8              0        11.4
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 수도권                   9.1            6.3           9.2    0.0         0.2
# 영남권                   4.5            2.3          11.1    0.5         0.4
# 충청권                   7.4            3.6          12.2    0.9           0
# 호남권                     0            5.4          10.5    3.0           0

# %%
df_2019_city = df_2019_city.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2019_city
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 수도권               38.1          23.2             1.5         12.3
# 영남권               34.0          33.1             2.4         11.7
# 충청권               35.5          26.7             5.7          8.1
# 호남권               64.9           4.8             0.0         11.4
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  모름/ 무응답 (%)
# 특성별(2)
# 수도권                    9.1             6.3            9.2     0.0          0.2
# 영남권                    4.5             2.3           11.1     0.5          0.4
# 충청권                    7.4             3.6           12.2     0.9          0.0
# 호남권                    0.0             5.4           10.5     3.0          0.0

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2019_city.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="권역별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# # =========================

# %% [markdown]
# #### *2020년도 데이터

# %%
df_2020 = df.iloc[0:, 11:21]
df_2020
# Out:
#              사업체수 (개).1 연구개발 지원 확대 (%).1 저리 자금 지원 (%).1 특허 및 인증 지원 (%).1  \
# 특성별(2)
# 제조업용 로봇             558             30.6           30.0              1.7
# 전문서비스용 로봇           331             45.8           20.7              4.3
# 개인서비스용 로봇           127             40.8           23.4              1.3
# 로봇부품 및 소프트웨어       1411             33.1           30.4              1.0
# 로봇 시스템              612             24.1           26.8              2.5
# 로봇 임베디드             164             39.3           21.9              4.5
# 로봇 서비스             1137             16.1           36.0              2.6
# 1억원 미만              830             22.2           40.9              3.9
# 1~5억원 미만           1435             30.6           31.7              2.1
# 5~10억원 미만           705             30.0           29.3              1.5
# 1~10억원 미만             -                -              -                -
# 10~30억원 미만          823             30.6           24.3              2.2
# ...

# %%
convert_col_name = ["사업체수 (개)", "연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

df_2020.rename(columns={df_2020.columns[0]:convert_col_name[0],
								df_2020.columns[1]:convert_col_name[1],
								df_2020.columns[2]:convert_col_name[2],
								df_2020.columns[3]:convert_col_name[3],
								df_2020.columns[4]:convert_col_name[4],
								df_2020.columns[5]:convert_col_name[5],
								df_2020.columns[6]:convert_col_name[6],
								df_2020.columns[7]:convert_col_name[7],
								df_2020.columns[8]:convert_col_name[8],
                                df_2020.columns[9]:convert_col_name[9],
                                },
								inplace=True)

df_2020
# Out:
#              사업체수 (개) 연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇           558           30.6         30.0            1.7         9.6
# 전문서비스용 로봇         331           45.8         20.7            4.3         3.8
# 개인서비스용 로봇         127           40.8         23.4            1.3         0.8
# 로봇부품 및 소프트웨어     1411           33.1         30.4            1.0        15.9
# 로봇 시스템            612           24.1         26.8            2.5        11.8
# 로봇 임베디드           164           39.3         21.9            4.5         5.3
# 로봇 서비스           1137           16.1         36.0            2.6        24.0
# 1억원 미만            830           22.2         40.9            3.9        17.2
# 1~5억원 미만         1435           30.6         31.7            2.1        15.9
# 5~10억원 미만         705           30.0         29.3            1.5        17.7
# 1~10억원 미만           -              -            -              -           -
# ...

# %% [markdown]
# ##### 2020년도 업종별 데이터

# %%
df_2020_jobtype = df_2020.iloc[0:7, 1:]
df_2020_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                30.6         30.0            1.7         9.6
# 전문서비스용 로봇              45.8         20.7            4.3         3.8
# 개인서비스용 로봇              40.8         23.4            1.3         0.8
# 로봇부품 및 소프트웨어           33.1         30.4            1.0        15.9
# 로봇 시스템                 24.1         26.8            2.5        11.8
# 로봇 임베디드                39.3         21.9            4.5         5.3
# 로봇 서비스                 16.1         36.0            2.6        24.0
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%)  \
# 특성별(2)
# 제조업용 로봇                     1.6            5.7          15.0    0.0
# 전문서비스용 로봇                   4.8            5.4           3.7    0.0
# 개인서비스용 로봇                   3.4            1.3           5.5    0.0
# 로봇부품 및 소프트웨어                4.5            4.4           7.7    0.0
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2020_jobtype[name] = df_2020_jobtype[name].str.replace('-', '0')

df_2020_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                30.6         30.0            1.7         9.6
# 전문서비스용 로봇              45.8         20.7            4.3         3.8
# 개인서비스용 로봇              40.8         23.4            1.3         0.8
# 로봇부품 및 소프트웨어           33.1         30.4            1.0        15.9
# 로봇 시스템                 24.1         26.8            2.5        11.8
# 로봇 임베디드                39.3         21.9            4.5         5.3
# 로봇 서비스                 16.1         36.0            2.6        24.0
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%)  \
# 특성별(2)
# 제조업용 로봇                     1.6            5.7          15.0    0.0
# 전문서비스용 로봇                   4.8            5.4           3.7    0.0
# 개인서비스용 로봇                   3.4            1.3           5.5    0.0
# 로봇부품 및 소프트웨어                4.5            4.4           7.7    0.0
# ...

# %%
df_2020_jobtype = df_2020_jobtype.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2020_jobtype
# Out:
#               연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                 30.6          30.0             1.7          9.6
# 전문서비스용 로봇               45.8          20.7             4.3          3.8
# 개인서비스용 로봇               40.8          23.4             1.3          0.8
# 로봇부품 및 소프트웨어            33.1          30.4             1.0         15.9
# 로봇 시스템                  24.1          26.8             2.5         11.8
# 로봇 임베디드                 39.3          21.9             4.5          5.3
# 로봇 서비스                  16.1          36.0             2.6         24.0
#
#               해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 제조업용 로봇                      1.6             5.7           15.0     0.0
# 전문서비스용 로봇                    4.8             5.4            3.7     0.0
# 개인서비스용 로봇                    3.4             1.3            5.5     0.0
# 로봇부품 및 소프트웨어                 4.5             4.4            7.7     0.0
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2020_jobtype.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="업종별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2020년도 매출액별 데이터

# %%
df_2020_output = df_2020.iloc[7:16, 1:]
df_2020_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                22.2         40.9            3.9        17.2
# 1~5억원 미만              30.6         31.7            2.1        15.9
# 5~10억원 미만             30.0         29.3            1.5        17.7
# 1~10억원 미만                -            -              -           -
# 10~30억원 미만            30.6         24.3            2.2        10.8
# 30억원 이상               27.3         18.7            0.0        11.0
# 10~50억원 미만               -            -              -           -
# 50~100억원 미만              -            -              -           -
# 100억원 이상                 -            -              -           -
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1억원 미만                     3.9            5.2           5.2    0.0         1.4
# 1~5억원 미만                   3.4            7.3           7.5    0.1         1.3
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2020_output[name] = df_2020_output[name].str.replace('-', '0')

df_2020_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                22.2         40.9            3.9        17.2
# 1~5억원 미만              30.6         31.7            2.1        15.9
# 5~10억원 미만             30.0         29.3            1.5        17.7
# 1~10억원 미만                0            0              0           0
# 10~30억원 미만            30.6         24.3            2.2        10.8
# 30억원 이상               27.3         18.7            0.0        11.0
# 10~50억원 미만               0            0              0           0
# 50~100억원 미만              0            0              0           0
# 100억원 이상                 0            0              0           0
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1억원 미만                     3.9            5.2           5.2    0.0         1.4
# 1~5억원 미만                   3.4            7.3           7.5    0.1         1.3
# ...

# %%
df_2020_output = df_2020_output.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2020_output
# Out:
#              연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                 22.2          40.9             3.9         17.2
# 1~5억원 미만               30.6          31.7             2.1         15.9
# 5~10억원 미만              30.0          29.3             1.5         17.7
# 1~10억원 미만               0.0           0.0             0.0          0.0
# 10~30억원 미만             30.6          24.3             2.2         10.8
# 30억원 이상                27.3          18.7             0.0         11.0
# 10~50억원 미만              0.0           0.0             0.0          0.0
# 50~100억원 미만             0.0           0.0             0.0          0.0
# 100억원 이상                0.0           0.0             0.0          0.0
#
#              해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 1억원 미만                      3.9             5.2            5.2     0.0
# 1~5억원 미만                    3.4             7.3            7.5     0.1
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2020_output.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="매출액별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2020년도 종사자수별 데이터

# %%
df_2020_workers = df_2020.iloc[16:20, 1:]
df_2020_workers
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1~4인             19.9         38.3            1.8        21.6
# 5~9인             28.6         32.7            3.6        13.8
# 10~49인           40.1         19.1            1.2         7.6
# 50인 이상           31.2         11.1            0.7         8.3
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 1~4인                  3.2            7.1           7.3    0.0         0.8
# 5~9인                  3.9            4.4           8.9    0.0         4.0
# 10~49인                3.6            6.4          14.1    0.4         7.5
# 50인 이상                7.5            0.0           8.1    0.9        32.3

# %%
df_2020_workers = df_2020_workers.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2020_workers
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1~4인              19.9          38.3             1.8         21.6
# 5~9인              28.6          32.7             3.6         13.8
# 10~49인            40.1          19.1             1.2          7.6
# 50인 이상            31.2          11.1             0.7          8.3
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  모름/ 무응답 (%)
# 특성별(2)
# 1~4인                   3.2             7.1            7.3     0.0          0.8
# 5~9인                   3.9             4.4            8.9     0.0          4.0
# 10~49인                 3.6             6.4           14.1     0.4          7.5
# 50인 이상                 7.5             0.0            8.1     0.9         32.3

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2020_workers.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="종사자수별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2020년도 권역별 데이터

# %%
df_2020_city = df_2020.iloc[20:24, 1:]
df_2020_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              30.3         24.3            2.7         9.9
# 영남권              20.1         35.6            1.7        23.8
# 충청권              28.9         38.8            2.1        10.3
# 호남권              54.2         30.0            0.0        14.1
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 수도권                   4.8            8.1          12.3    0.1         7.5
# 영남권                   3.9            5.1           6.1    0.3         3.4
# 충청권                   0.2            1.0          14.5    0.2         4.1
# 호남권                   0.8            0.5           0.0    0.0         0.3

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2020_city[name] = df_2020_city[name].str.replace('-', '0')

df_2020_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              30.3         24.3            2.7         9.9
# 영남권              20.1         35.6            1.7        23.8
# 충청권              28.9         38.8            2.1        10.3
# 호남권              54.2         30.0            0.0        14.1
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 모름/ 무응답 (%)
# 특성별(2)
# 수도권                   4.8            8.1          12.3    0.1         7.5
# 영남권                   3.9            5.1           6.1    0.3         3.4
# 충청권                   0.2            1.0          14.5    0.2         4.1
# 호남권                   0.8            0.5           0.0    0.0         0.3

# %%
df_2020_city = df_2020_city.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2020_city
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 수도권               30.3          24.3             2.7          9.9
# 영남권               20.1          35.6             1.7         23.8
# 충청권               28.9          38.8             2.1         10.3
# 호남권               54.2          30.0             0.0         14.1
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  모름/ 무응답 (%)
# 특성별(2)
# 수도권                    4.8             8.1           12.3     0.1          7.5
# 영남권                    3.9             5.1            6.1     0.3          3.4
# 충청권                    0.2             1.0           14.5     0.2          4.1
# 호남권                    0.8             0.5            0.0     0.0          0.3

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2020_city.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="권역별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# # ==========================

# %% [markdown]
# #### *2021년도 데이터

# %%
df_2021 = df.iloc[0:, 21:32]
df_2021
# Out:
#              사업체수 (개).2 연구개발 지원 확대 (%).2 저리 자금 지원 (%).2 특허 및 인증 지원 (%).2  \
# 특성별(2)
# 제조업용 로봇             565             22.5           47.7              0.0
# 전문서비스용 로봇           355             37.7           35.4              4.6
# 개인서비스용 로봇           161             26.5           36.1              3.7
# 로봇부품 및 소프트웨어       1419             21.5           55.0              1.5
# 로봇 시스템              644             22.9           51.4              2.8
# 로봇 임베디드             171             30.7           28.2              8.2
# 로봇 서비스             1156             16.7           45.2              0.6
# 1억원 미만              780             16.1           56.1              0.6
# 1~5억원 미만              -                -              -                -
# 5~10억원 미만             -                -              -                -
# 1~10억원 미만          2243             23.1           49.7              1.6
# 10~30억원 미만            -                -              -                -
# ...

# %%
convert_col_name = ["사업체수 (개)", "연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "없음 (%)", "모름/ 무응답 (%)"]

df_2021.rename(columns={df_2021.columns[0]:convert_col_name[0],
								df_2021.columns[1]:convert_col_name[1],
								df_2021.columns[2]:convert_col_name[2],
								df_2021.columns[3]:convert_col_name[3],
								df_2021.columns[4]:convert_col_name[4],
								df_2021.columns[5]:convert_col_name[5],
								df_2021.columns[6]:convert_col_name[6],
								df_2021.columns[7]:convert_col_name[7],
								df_2021.columns[8]:convert_col_name[8],
                                df_2021.columns[9]:convert_col_name[9],
                                df_2021.columns[10]:convert_col_name[10],
                                },
								inplace=True)

df_2021
# Out:
#              사업체수 (개) 연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇           565           22.5         47.7            0.0         5.7
# 전문서비스용 로봇         355           37.7         35.4            4.6         2.5
# 개인서비스용 로봇         161           26.5         36.1            3.7        12.0
# 로봇부품 및 소프트웨어     1419           21.5         55.0            1.5         6.5
# 로봇 시스템            644           22.9         51.4            2.8         6.7
# 로봇 임베디드           171           30.7         28.2            8.2         2.0
# 로봇 서비스           1156           16.7         45.2            0.6        16.2
# 1억원 미만            780           16.1         56.1            0.6        11.9
# 1~5억원 미만            -              -            -              -           -
# 5~10억원 미만           -              -            -              -           -
# 1~10억원 미만        2243           23.1         49.7            1.6         7.5
# ...

# %% [markdown]
# ##### 2021년도 업종별 데이터

# %%
df_2021_jobtype = df_2021.iloc[0:7, 1:]
df_2021_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                22.5         47.7            0.0         5.7
# 전문서비스용 로봇              37.7         35.4            4.6         2.5
# 개인서비스용 로봇              26.5         36.1            3.7        12.0
# 로봇부품 및 소프트웨어           21.5         55.0            1.5         6.5
# 로봇 시스템                 22.9         51.4            2.8         6.7
# 로봇 임베디드                30.7         28.2            8.2         2.0
# 로봇 서비스                 16.7         45.2            0.6        16.2
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 제조업용 로봇                     2.2            4.8           1.1    0.0    0.0
# 전문서비스용 로봇                   4.2            7.0           7.2    0.0    0.0
# 개인서비스용 로봇                   0.7            0.7          17.1    0.0    0.0
# 로봇부품 및 소프트웨어                3.1            6.1           5.5    0.4    0.0
# ...

# %%
df_2021_jobtype = df_2021_jobtype.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2021_jobtype
# Out:
#               연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                 22.5          47.7             0.0          5.7
# 전문서비스용 로봇               37.7          35.4             4.6          2.5
# 개인서비스용 로봇               26.5          36.1             3.7         12.0
# 로봇부품 및 소프트웨어            21.5          55.0             1.5          6.5
# 로봇 시스템                  22.9          51.4             2.8          6.7
# 로봇 임베디드                 30.7          28.2             8.2          2.0
# 로봇 서비스                  16.7          45.2             0.6         16.2
#
#               해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 제조업용 로봇                      2.2             4.8            1.1     0.0
# 전문서비스용 로봇                    4.2             7.0            7.2     0.0
# 개인서비스용 로봇                    0.7             0.7           17.1     0.0
# 로봇부품 및 소프트웨어                 3.1             6.1            5.5     0.4
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2021_jobtype.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="업종별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2021년도 매출액별 데이터

# %%
df_2021_output = df_2021.iloc[7:16, 1:]
df_2021_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                16.1         56.1            0.6        11.9
# 1~5억원 미만                 -            -              -           -
# 5~10억원 미만                -            -              -           -
# 1~10억원 미만             23.1         49.7            1.6         7.5
# 10~30억원 미만               -            -              -           -
# 30억원 이상                  -            -              -           -
# 10~50억원 미만            22.8         43.2            2.9         8.5
# 50~100억원 미만           32.8         40.3            3.5         9.4
# 100억원 이상              33.7         15.5            1.5         9.6
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1억원 미만                     0.8            2.8          10.2    0.0    0.0
# 1~5억원 미만                     -              -             -      -      -
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "없음 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2021_output[name] = df_2021_output[name].str.replace('-', '0')

df_2021_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                16.1         56.1            0.6        11.9
# 1~5억원 미만                 0            0              0           0
# 5~10억원 미만                0            0              0           0
# 1~10억원 미만             23.1         49.7            1.6         7.5
# 10~30억원 미만               0            0              0           0
# 30억원 이상                  0            0              0           0
# 10~50억원 미만            22.8         43.2            2.9         8.5
# 50~100억원 미만           32.8         40.3            3.5         9.4
# 100억원 이상              33.7         15.5            1.5         9.6
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1억원 미만                     0.8            2.8          10.2    0.0    0.0
# 1~5억원 미만                     0              0             0      0      0
# ...

# %%
df_2021_output = df_2021_output.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2021_output
# Out:
#              연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                 16.1          56.1             0.6         11.9
# 1~5억원 미만                0.0           0.0             0.0          0.0
# 5~10억원 미만               0.0           0.0             0.0          0.0
# 1~10억원 미만              23.1          49.7             1.6          7.5
# 10~30억원 미만              0.0           0.0             0.0          0.0
# 30억원 이상                 0.0           0.0             0.0          0.0
# 10~50억원 미만             22.8          43.2             2.9          8.5
# 50~100억원 미만            32.8          40.3             3.5          9.4
# 100억원 이상               33.7          15.5             1.5          9.6
#
#              해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 1억원 미만                      0.8             2.8           10.2     0.0
# 1~5억원 미만                    0.0             0.0            0.0     0.0
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2021_output.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="매출액별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2021년도 종사자수별 데이터

# %%
df_2021_workers = df_2021.iloc[16:20, 1:]
df_2021_workers
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1~4인             15.9         60.3            0.6         8.0
# 5~9인             21.3         46.7            1.9         9.5
# 10~49인           32.3         35.0            3.3         8.4
# 50인 이상           35.1         11.4            5.1        10.7
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1~4인                  1.4            4.7           6.9    0.3    0.0
# 5~9인                  3.9            4.8           7.7    0.0    0.0
# 10~49인                4.6            4.9           8.1    0.0    0.0
# 50인 이상                5.9            7.0           7.5    0.0    0.4
#
#        모름/ 무응답 (%)
# 특성별(2)
# 1~4인           1.9
# 5~9인           4.2
# 10~49인         3.5
# 50인 이상        17.0

# %%
df_2021_workers = df_2021_workers.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2021_workers
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1~4인              15.9          60.3             0.6          8.0
# 5~9인              21.3          46.7             1.9          9.5
# 10~49인            32.3          35.0             3.3          8.4
# 50인 이상            35.1          11.4             5.1         10.7
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  없음 (%)  \
# 특성별(2)
# 1~4인                   1.4             4.7            6.9     0.3     0.0
# 5~9인                   3.9             4.8            7.7     0.0     0.0
# 10~49인                 4.6             4.9            8.1     0.0     0.0
# 50인 이상                 5.9             7.0            7.5     0.0     0.4
#
#         모름/ 무응답 (%)
# 특성별(2)
# 1~4인            1.9
# 5~9인            4.2
# 10~49인          3.5
# 50인 이상         17.0

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2021_workers.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="종사자수별")
ax.xaxis.tick_top()
plt.show(ax)

# %%
df_2021_city = df_2021.iloc[20:24, 1:]
df_2021_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              23.5         44.9            1.8         9.0
# 영남권              18.0         52.8            0.7         9.5
# 충청권              23.2         49.3            4.9         7.3
# 호남권              33.5         42.2            2.8         4.1
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 수도권                   3.6            3.7           8.0    0.2    0.0
# 영남권                   3.5            6.5           7.1    0.0    0.1
# 충청권                   0.4            5.1           5.1    0.0    0.0
# 호남권                   2.5            6.2           8.0    0.0    0.0
#
#        모름/ 무응답 (%)
# 특성별(2)
# 수도권            5.2
# 영남권            1.8
# 충청권            4.7
# 호남권            0.9

# %%
df_2021_city = df_2021_city.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2021_city
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 수도권               23.5          44.9             1.8          9.0
# 영남권               18.0          52.8             0.7          9.5
# 충청권               23.2          49.3             4.9          7.3
# 호남권               33.5          42.2             2.8          4.1
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  없음 (%)  \
# 특성별(2)
# 수도권                    3.6             3.7            8.0     0.2     0.0
# 영남권                    3.5             6.5            7.1     0.0     0.1
# 충청권                    0.4             5.1            5.1     0.0     0.0
# 호남권                    2.5             6.2            8.0     0.0     0.0
#
#         모름/ 무응답 (%)
# 특성별(2)
# 수도권             5.2
# 영남권             1.8
# 충청권             4.7
# 호남권             0.9

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2021_city.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="권역별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# # =============================

# %% [markdown]
# #### *2022년도 데이터

# %%
df_2022 = df.iloc[0:, 32:43]
df_2022
# Out:
#              사업체수 (개).3 연구개발 지원 확대 (%).3 저리 자금 지원 (%).3 특허 및 인증 지원 (%).3  \
# 특성별(2)
# 제조업용 로봇             568             15.7           52.9              8.6
# 전문서비스용 로봇           360             25.5           50.9              7.0
# 개인서비스용 로봇           161             35.9           37.7              1.4
# 로봇부품 및 소프트웨어       1420             18.1           54.2              2.8
# 로봇 시스템              649             20.4           50.6              1.8
# 로봇 임베디드             179             19.0           39.9              0.0
# 로봇 서비스             1168              9.8           44.7              0.6
# 1억원 미만             1017             15.2           48.1              2.5
# 1~5억원 미만              -                -              -                -
# 5~10억원 미만             -                -              -                -
# 1~10억원 미만          2005             15.7           55.2              3.3
# 10~30억원 미만            -                -              -                -
# ...

# %%
convert_col_name = ["사업체수 (개)", "연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "없음 (%)", "모름/ 무응답 (%)"]

df_2022.rename(columns={df_2022.columns[0]:convert_col_name[0],
								df_2022.columns[1]:convert_col_name[1],
								df_2022.columns[2]:convert_col_name[2],
								df_2022.columns[3]:convert_col_name[3],
								df_2022.columns[4]:convert_col_name[4],
								df_2022.columns[5]:convert_col_name[5],
								df_2022.columns[6]:convert_col_name[6],
								df_2022.columns[7]:convert_col_name[7],
								df_2022.columns[8]:convert_col_name[8],
                                df_2022.columns[9]:convert_col_name[9],
                                df_2022.columns[10]:convert_col_name[10],
                                },
								inplace=True)

df_2022
# Out:
#              사업체수 (개) 연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇           568           15.7         52.9            8.6         8.0
# 전문서비스용 로봇         360           25.5         50.9            7.0         0.9
# 개인서비스용 로봇         161           35.9         37.7            1.4         2.3
# 로봇부품 및 소프트웨어     1420           18.1         54.2            2.8         7.9
# 로봇 시스템            649           20.4         50.6            1.8         9.2
# 로봇 임베디드           179           19.0         39.9            0.0        10.8
# 로봇 서비스           1168            9.8         44.7            0.6        13.9
# 1억원 미만           1017           15.2         48.1            2.5        10.3
# 1~5억원 미만            -              -            -              -           -
# 5~10억원 미만           -              -            -              -           -
# 1~10억원 미만        2005           15.7         55.2            3.3         9.1
# ...

# %% [markdown]
# ##### 2022년도 업종별 데이터

# %%
df_2022_jobtype = df_2022.iloc[0:7, 1:]
df_2022_jobtype
# Out:
#              연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                15.7         52.9            8.6         8.0
# 전문서비스용 로봇              25.5         50.9            7.0         0.9
# 개인서비스용 로봇              35.9         37.7            1.4         2.3
# 로봇부품 및 소프트웨어           18.1         54.2            2.8         7.9
# 로봇 시스템                 20.4         50.6            1.8         9.2
# 로봇 임베디드                19.0         39.9            0.0        10.8
# 로봇 서비스                  9.8         44.7            0.6        13.9
#
#              해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 제조업용 로봇                     3.2            4.7           2.1    0.0    0.0
# 전문서비스용 로봇                   0.0            0.6           5.6    1.1    0.6
# 개인서비스용 로봇                   1.2            6.3          10.2    0.0    0.0
# 로봇부품 및 소프트웨어                1.4            4.4           9.2    0.4    0.9
# ...

# %%
df_2022_jobtype = df_2022_jobtype.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2022_jobtype
# Out:
#               연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 제조업용 로봇                 15.7          52.9             8.6          8.0
# 전문서비스용 로봇               25.5          50.9             7.0          0.9
# 개인서비스용 로봇               35.9          37.7             1.4          2.3
# 로봇부품 및 소프트웨어            18.1          54.2             2.8          7.9
# 로봇 시스템                  20.4          50.6             1.8          9.2
# 로봇 임베디드                 19.0          39.9             0.0         10.8
# 로봇 서비스                   9.8          44.7             0.6         13.9
#
#               해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 제조업용 로봇                      3.2             4.7            2.1     0.0
# 전문서비스용 로봇                    0.0             0.6            5.6     1.1
# 개인서비스용 로봇                    1.2             6.3           10.2     0.0
# 로봇부품 및 소프트웨어                 1.4             4.4            9.2     0.4
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2022_jobtype.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="업종별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2022년도 매출액별 데이터

# %%
df_2022_output = df_2022.iloc[7:16, 1:]
df_2022_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                15.2         48.1            2.5        10.3
# 1~5억원 미만                 -            -              -           -
# 5~10억원 미만                -            -              -           -
# 1~10억원 미만             15.7         55.2            3.3         9.1
# 10~30억원 미만               -            -              -           -
# 30억원 이상                  -            -              -           -
# 10~50억원 미만            19.0         46.3            3.3         9.1
# 50~100억원 미만           27.6         44.2            1.1         3.1
# 100억원 이상              25.7         16.7            2.8         5.6
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1억원 미만                     1.0            5.8          16.0    0.8    0.3
# 1~5억원 미만                     -              -             -      -      -
# ...

# %%
convert_col_name = ["연구개발 지원 확대 (%)", "저리 자금 지원 (%)", "특허 및 인증 지원 (%)", "업체 간 연계 (%)", "해외 진출 및 사업화 지원 (%)", "관련 기술정보 지원 (%)", "채용 장려금 지원 (%)", "기타 (%)", "없음 (%)", "모름/ 무응답 (%)"]

for name in convert_col_name:
	df_2022_output[name] = df_2022_output[name].str.replace('-', '0')

df_2022_output
# Out:
#             연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                15.2         48.1            2.5        10.3
# 1~5억원 미만                 0            0              0           0
# 5~10억원 미만                0            0              0           0
# 1~10억원 미만             15.7         55.2            3.3         9.1
# 10~30억원 미만               0            0              0           0
# 30억원 이상                  0            0              0           0
# 10~50억원 미만            19.0         46.3            3.3         9.1
# 50~100억원 미만           27.6         44.2            1.1         3.1
# 100억원 이상              25.7         16.7            2.8         5.6
#
#             해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1억원 미만                     1.0            5.8          16.0    0.8    0.3
# 1~5억원 미만                     0              0             0      0      0
# ...

# %%
df_2022_output = df_2022_output.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2022_output
# Out:
#              연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1억원 미만                 15.2          48.1             2.5         10.3
# 1~5억원 미만                0.0           0.0             0.0          0.0
# 5~10억원 미만               0.0           0.0             0.0          0.0
# 1~10억원 미만              15.7          55.2             3.3          9.1
# 10~30억원 미만              0.0           0.0             0.0          0.0
# 30억원 이상                 0.0           0.0             0.0          0.0
# 10~50억원 미만             19.0          46.3             3.3          9.1
# 50~100억원 미만            27.6          44.2             1.1          3.1
# 100억원 이상               25.7          16.7             2.8          5.6
#
#              해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  \
# 특성별(2)
# 1억원 미만                      1.0             5.8           16.0     0.8
# 1~5억원 미만                    0.0             0.0            0.0     0.0
# ...

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2022_output.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="매출액별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2022년도 종사자수별 데이터

# %%
df_2022_workers = df_2022.iloc[16:20, 1:]
df_2022_workers
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 1~4인             12.5         56.9            2.5        11.2
# 5~9인             18.5         49.0            4.9         7.4
# 10~49인           21.2         44.9            2.5         7.4
# 50인 이상           32.9         14.3            1.9         5.1
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 1~4인                  0.9            5.4           8.8    0.4    1.0
# 5~9인                  1.5            6.0          12.1    0.0    0.5
# 10~49인                2.8            6.8          10.1    0.3    0.0
# 50인 이상                4.3            6.6           6.4    2.1    3.3
#
#        모름/ 무응답 (%)
# 특성별(2)
# 1~4인           0.5
# 5~9인           0.1
# 10~49인         4.1
# 50인 이상        23.1

# %%
df_2022_workers = df_2022_workers.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2022_workers
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 1~4인              12.5          56.9             2.5         11.2
# 5~9인              18.5          49.0             4.9          7.4
# 10~49인            21.2          44.9             2.5          7.4
# 50인 이상            32.9          14.3             1.9          5.1
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  없음 (%)  \
# 특성별(2)
# 1~4인                   0.9             5.4            8.8     0.4     1.0
# 5~9인                   1.5             6.0           12.1     0.0     0.5
# 10~49인                 2.8             6.8           10.1     0.3     0.0
# 50인 이상                 4.3             6.6            6.4     2.1     3.3
#
#         모름/ 무응답 (%)
# 특성별(2)
# 1~4인            0.5
# 5~9인            0.1
# 10~49인          4.1
# 50인 이상         23.1

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2022_workers.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="종사자수별")
ax.xaxis.tick_top()
plt.show(ax)

# %% [markdown]
# ##### 2022년도 권역별 데이터

# %%
df_2022_city = df_2022.iloc[20:24, 1:]
df_2022_city
# Out:
#        연구개발 지원 확대 (%) 저리 자금 지원 (%) 특허 및 인증 지원 (%) 업체 간 연계 (%)  \
# 특성별(2)
# 수도권              17.8         46.6            2.8        10.6
# 영남권              13.5         56.2            2.6         9.2
# 충청권              17.5         46.7            5.3         3.4
# 호남권              33.7         47.5            1.7         3.7
#
#        해외 진출 및 사업화 지원 (%) 관련 기술정보 지원 (%) 채용 장려금 지원 (%) 기타 (%) 없음 (%)  \
# 특성별(2)
# 수도권                   2.8            5.9           8.4    0.2    1.1
# 영남권                   0.2            5.2          11.0    1.0    0.2
# 충청권                   1.0            9.1          13.2    0.0    1.3
# 호남권                   1.6            4.4           6.9    0.0    0.0
#
#        모름/ 무응답 (%)
# 특성별(2)
# 수도권            3.8
# 영남권            1.0
# 충청권            2.4
# 호남권            0.4

# %%
df_2022_city = df_2022_city.astype(dtype={"연구개발 지원 확대 (%)":"float",
                                                "저리 자금 지원 (%)":"float",
                                                "특허 및 인증 지원 (%)":"float",
                                                "업체 간 연계 (%)":"float",
                                                "해외 진출 및 사업화 지원 (%)":"float",
                                                "관련 기술정보 지원 (%)":"float",
                                                "채용 장려금 지원 (%)":"float", 
                                                "기타 (%)":"float",
                                                "없음 (%)":"float",
                                                "모름/ 무응답 (%)":"float"},
                                                errors="raise",
                                                copy=True)

df_2022_city
# Out:
#         연구개발 지원 확대 (%)  저리 자금 지원 (%)  특허 및 인증 지원 (%)  업체 간 연계 (%)  \
# 특성별(2)
# 수도권               17.8          46.6             2.8         10.6
# 영남권               13.5          56.2             2.6          9.2
# 충청권               17.5          46.7             5.3          3.4
# 호남권               33.7          47.5             1.7          3.7
#
#         해외 진출 및 사업화 지원 (%)  관련 기술정보 지원 (%)  채용 장려금 지원 (%)  기타 (%)  없음 (%)  \
# 특성별(2)
# 수도권                    2.8             5.9            8.4     0.2     1.1
# 영남권                    0.2             5.2           11.0     1.0     0.2
# 충청권                    1.0             9.1           13.2     0.0     1.3
# 호남권                    1.6             4.4            6.9     0.0     0.0
#
#         모름/ 무응답 (%)
# 특성별(2)
# 수도권             3.8
# 영남권             1.0
# 충청권             2.4
# 호남권             0.4

# %%
plt.figure(figsize=(30, 8))
ax = sns.heatmap(df_2022_city.iloc[:, :], annot=True, fmt='.1f', linewidths=0.7, annot_kws={"size": 20})
ax.set(xlabel="정부지원 필요분야", ylabel="권역별")
ax.xaxis.tick_top()
plt.show(ax)

# %%
obstacle_1 = pd.read_csv("../data/gov_supp.csv", usecols=["특성별(2)", "2019.2", "2020.2", "2021.2", "2022.2"], encoding="EUC-KR")
obstacle_1.set_index('특성별(2)', inplace=True)
obstacle_1.drop('소계', inplace=True)

convert_col_name = ["2019", "2020", "2021", "2022"]

obstacle_1.rename(columns={obstacle_1.columns[0]:convert_col_name[0],
                            obstacle_1.columns[1]:convert_col_name[1],
                            obstacle_1.columns[2]:convert_col_name[2],
                            obstacle_1.columns[3]:convert_col_name[3],
                            },
                            inplace=True)

obstacle_1
# Out:
#                       2019          2020          2021          2022
# 특성별(2)
# 특성별(2)        저리 자금 지원 (%)  저리 자금 지원 (%)  저리 자금 지원 (%)  저리 자금 지원 (%)
# 제조업용 로봇               16.1          30.0          47.7          52.9
# 전문서비스용 로봇             27.2          20.7          35.4          50.9
# 개인서비스용 로봇             21.6          23.4          36.1          37.7
# 로봇부품 및 소프트웨어          22.8          30.4          55.0          54.2
# 로봇 시스템                22.5          26.8          51.4          50.6
# 로봇 임베디드               10.9          21.9          28.2          39.9
# 로봇 서비스                36.4          36.0          45.2          44.7
# 1억원 미만                29.8          40.9          56.1          48.1
# 1~5억원 미만              28.8          31.7             -             -
# 5~10억원 미만             23.1          29.3             -             -
# 1~10억원 미만                -             -          49.7          55.2
# ...

# %%
res_jobtype =obstacle_1.iloc[4:5, :]
res_jobtype = res_jobtype.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)
res_jobtype
# Out:
#               2019  2020  2021  2022
# 특성별(2)
# 로봇부품 및 소프트웨어  22.8  30.4  55.0  54.2

# %%
res_output =obstacle_1.iloc[9:12, :]

convert_col_name = ["2019", "2020", "2021", "2022"]

for name in convert_col_name:
	res_output[name] = res_output[name].str.replace('-', '0')

res_output = res_output.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)

res_output.loc['1~10억원 미만', '2019'] = res_output.loc['1~5억원 미만', '2019'] + res_output.loc['5~10억원 미만', '2019']
res_output.loc['1~10억원 미만', '2020'] = res_output.loc['1~5억원 미만', '2020'] + res_output.loc['5~10억원 미만', '2020']
res_output.drop("1~5억원 미만", inplace=True)
res_output.drop("5~10억원 미만", inplace=True)

res_output
# Out:
# /tmp/ipykernel_5820/1866916286.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_output[name] = res_output[name].str.replace('-', '0')
#            2019  2020  2021  2022
# 특성별(2)
# 1~10억원 미만  51.9  61.0  49.7  55.2

# %%
res_workers =obstacle_1.iloc[20:21, :]
res_workers = res_workers.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)
res_workers
# Out:
#         2019  2020  2021  2022
# 특성별(2)
# 50인 이상  22.8  11.1  11.4  14.3

# %%
res_city = obstacle_1.iloc[21:22, :]
res_city = res_city.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)
res_city
# Out:
#         2019  2020  2021  2022
# 특성별(2)
# 수도권     23.2  24.3  44.9  46.6

# %%
# 모든 데이터프레임을 합치기
combined_df = pd.concat([res_jobtype, res_output, res_workers, res_city])

# 그래프 그리기
plt.figure(figsize=(10, 6))
for index, row in combined_df.iterrows():
    plt.plot(row.index, row.values, marker='o', label=index)

# 그래프 설정
plt.title('정부지원 필요분야: 저리 자금 지원', fontsize=16, fontweight='bold', color='red')
plt.ylabel('비율 (%)', fontsize=12)
plt.xlabel('연도', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='특성별', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()


plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs = axs.flatten()  # 2D 배열을 1D로 변환

# 각 데이터프레임을 서브플롯에 그리기
dataframes = [res_jobtype, res_output, res_workers, res_city]
titles = ['업종: 로봇부품 및 소프트웨어', '매출액: 1~10억원 미만', '종사자 수: 50인 이상', '권역: 수도권']

for ax, df, title in zip(axs, dataframes, titles):
    ax.plot(df.columns, df.values.flatten(), marker='o', color='red')
    ax.set_title(title, fontsize=12.5, fontweight='bold')
    ax.set_ylabel('비율 (%)', fontsize=12)
    ax.set_xlabel('연도', fontsize=12)
    ax.set_ylim(0, 75)
    ax.grid()

fig.suptitle('정부지원 필요분야: 저리 자금 지원', fontsize=18, fontweight='bold', color = "darkred")

plt.tight_layout()
plt.show()

# %%
obstacle_2 = pd.read_csv("../data/gov_supp.csv", usecols=["특성별(2)", "2019.1", "2020.1", "2021.1", "2022.1"], encoding="EUC-KR")
obstacle_2.set_index('특성별(2)', inplace=True)
obstacle_2.drop('소계', inplace=True)

convert_col_name = ["2019", "2020", "2021", "2022"]

obstacle_2.rename(columns={obstacle_2.columns[0]:convert_col_name[0],
                            obstacle_2.columns[1]:convert_col_name[1],
                            obstacle_2.columns[2]:convert_col_name[2],
                            obstacle_2.columns[3]:convert_col_name[3],
                            },
                            inplace=True)

for name in convert_col_name:
	obstacle_2[name] = obstacle_2[name].str.replace('-', '0')

obstacle_2
# Out:
#                         2019            2020            2021            2022
# 특성별(2)
# 특성별(2)        연구개발 지원 확대 (%)  연구개발 지원 확대 (%)  연구개발 지원 확대 (%)  연구개발 지원 확대 (%)
# 제조업용 로봇                 42.9            30.6            22.5            15.7
# 전문서비스용 로봇               47.0            45.8            37.7            25.5
# 개인서비스용 로봇               29.5            40.8            26.5            35.9
# 로봇부품 및 소프트웨어            39.6            33.1            21.5            18.1
# 로봇 시스템                  47.9            24.1            22.9            20.4
# 로봇 임베디드                 57.6            39.3            30.7            19.0
# 로봇 서비스                  22.9            16.1            16.7             9.8
# 1억원 미만                  37.1            22.2            16.1            15.2
# 1~5억원 미만                33.2            30.6               0               0
# 5~10억원 미만               42.0            30.0               0               0
# ...

# %%
res_jobtype2 =obstacle_1.iloc[4:5, :]
res_jobtype2 = res_jobtype2.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)

res_jobtype2
# Out:
#               2019  2020  2021  2022
# 특성별(2)
# 로봇부품 및 소프트웨어  22.8  30.4  55.0  54.2

# %%
res_output2 =obstacle_2.iloc[9:12 , :]

res_output2 = res_output2.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)

res_output2.loc['1~10억원 미만', '2019'] = res_output2.loc['1~5억원 미만', '2019'] + res_output2.loc['5~10억원 미만', '2019']
res_output2.loc['1~10억원 미만', '2020'] = res_output2.loc['1~5억원 미만', '2020'] + res_output2.loc['5~10억원 미만', '2020']

res_output2.drop("1~5억원 미만", inplace=True)
res_output2.drop("5~10억원 미만", inplace=True)

res_output2
# Out:
#            2019  2020  2021  2022
# 특성별(2)
# 1~10억원 미만  75.2  60.6  23.1  15.7

# %%
res_workers2 =obstacle_2.iloc[20:21, :]
res_workers2 = res_workers2.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)
res_workers2
# Out:
#         2019  2020  2021  2022
# 특성별(2)
# 50인 이상  39.0  31.2  35.1  32.9

# %%
res_city2 = obstacle_2.iloc[21:22, :]
res_city2 = res_city2.astype(dtype={"2019":"float",
                                        "2020":"float",
                                        "2021":"float",
                                        "2022":"float",
                                        },
                                        errors="raise",
                                        copy=True)
res_city2
# Out:
#         2019  2020  2021  2022
# 특성별(2)
# 수도권     38.1  30.3  23.5  17.8

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs = axs.flatten()  # 2D 배열을 1D로 변환

# 각 데이터프레임을 서브플롯에 그리기
dataframes = [res_jobtype2, res_output2, res_workers2, res_city2]
titles = ['업종: 로봇부품 및 소프트웨어', '매출액: 1~10억원 미만', '종사자 수: 50인 이상', '권역: 수도권']

for ax, df, title in zip(axs, dataframes, titles):
    ax.plot(df.columns, df.values.flatten(), marker='o', color='red')
    ax.set_title(title, fontsize=12.5, fontweight='bold')
    ax.set_ylabel('비율 (%)', fontsize=12)
    ax.set_xlabel('연도', fontsize=12)
    ax.set_ylim(0, 80)
    ax.grid()

fig.suptitle('정부지원 필요분야: 연구개발 지원 확대', fontsize=16, fontweight='bold', color = "darkred")

plt.tight_layout()
plt.show()
